# %% [markdown]
# <a href="https://colab.research.google.com/github/rutuja-patil24/CMPE-255-Data_Mining/blob/main/Assignment_6/EDA_ON_SPOTIFY_DATASET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data="/content/drive/MyDrive/tracks.csv"
df =pd.read_csv(data)

# %%
df.head()
# Out:
#                        id  ... time_signature
# 0  35iwgR4jXetI318WEWsa1Q  ...              3
# 1  021ht4sdgPcrDgSk7JTbKY  ...              1
# 2  07A5yehtSnoedViJAZkNnc  ...              5
# 3  08FmqUhxtyLTn6pAh6bk45  ...              3
# 4  08y9GfoqCWfOGsKdwojr5e  ...              4
#
# [5 rows x 20 columns]

# %%
df.describe()
# Out:
#           popularity   duration_ms  ...          tempo  time_signature
# count  586672.000000  5.866720e+05  ...  586672.000000   586672.000000
# mean       27.570053  2.300512e+05  ...     118.464857        3.873382
# std        18.370642  1.265261e+05  ...      29.764108        0.473162
# min         0.000000  3.344000e+03  ...       0.000000        0.000000
# 25%        13.000000  1.750930e+05  ...      95.600000        4.000000
# 50%        27.000000  2.148930e+05  ...     117.384000        4.000000
# 75%        41.000000  2.638670e+05  ...     136.321000        4.000000
# max       100.000000  5.621218e+06  ...     246.381000        5.000000
#
# [8 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.count()
# Out:
# id                  586672
# name                586601
# popularity          586672
# duration_ms         586672
# explicit            586672
# artists             586672
# id_artists          586672
# release_date        586672
# danceability        586672
# energy              586672
# key                 586672
# loudness            586672
# mode                586672
# speechiness         586672
# acousticness        586672
# instrumentalness    586672
# liveness            586672
# valence             586672
# tempo               586672
# time_signature      586672
# dtype: int64

# %%
df.nunique()
# Out:
# id                  586672
# name                446474
# popularity             101
# duration_ms         123122
# explicit                 2
# artists             114030
# id_artists          115062
# release_date         19700
# danceability          1285
# energy                2571
# key                     12
# loudness             29196
# mode                     2
# speechiness           1655
# acousticness          5217
# instrumentalness      5402
# liveness              1782
# valence               1805
# tempo               122706
# time_signature           5
# dtype: int64

# %%
plt.scatter(df.valence,df.energy)

# %%
df.corr()
# Out:
#                   popularity  duration_ms  ...     tempo  time_signature
# popularity          1.000000     0.027681  ...  0.071364        0.086759
# duration_ms         0.027681     1.000000  ... -0.001210        0.037552
# explicit            0.211758    -0.016747  ...  0.005745        0.044447
# danceability        0.187000    -0.120371  ... -0.040783        0.146196
# energy              0.302315     0.024825  ...  0.230099        0.188983
# key                 0.015299     0.004626  ...  0.004904        0.008928
# loudness            0.327028     0.000337  ...  0.189288        0.164377
# mode               -0.033655    -0.027610  ...  0.007871       -0.015892
# speechiness        -0.047357    -0.125771  ... -0.086911       -0.114171
# acousticness       -0.370882    -0.064434  ... -0.195235       -0.173927
# instrumentalness   -0.236487     0.069278  ... -0.055477       -0.042257
# liveness           -0.048740     0.002137  ... -0.014912       -0.024202
# ...

# %%
sns.heatmap(df.corr())

# %%
sns.displot(df, x="valence")

# %%
sns.displot(df, x="energy")

# %%
sns.displot(df, x="tempo")

# %%
sns.displot(df, x="danceability")

# %%
sns.displot(df, x="key")

# %%
sns.displot(df, x="loudness")

# %%
plt.boxplot(df["energy"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f1dc9855550>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1dc9756790>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1dc97ec2d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1dc98f2810>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f1dc9686b10>,
#   <matplotlib.lines.Line2D at 0x7f1dc966c150>]}

# %%
plt.boxplot(df["valence"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f1dd1ca1fd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1dd1d85f50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1dd1e908d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1dd2903650>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f1dd1ca1790>,
#   <matplotlib.lines.Line2D at 0x7f1dd1cb7fd0>]}

# %%
plt.boxplot(df["tempo"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f1dd2973290>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1dd1d32790>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1dd2925e10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1dd1e76290>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f1dd1d9b710>,
#   <matplotlib.lines.Line2D at 0x7f1dd1d9bb10>]}

# %%
plt.boxplot(df["key"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f1dc8855f90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1dc885cf90>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1dc87e3fd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1dc87e3a90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f1dc885c510>,
#   <matplotlib.lines.Line2D at 0x7f1dc885ca50>]}

# %%
plt.boxplot(df["danceability"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f1dc87c19d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1dc87c48d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1dc87cc910>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1dc87cc3d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f1dc87c1f10>,
#   <matplotlib.lines.Line2D at 0x7f1dc87c4390>]}

# %%
plt.boxplot(df["loudness"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f1dc872e450>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1dc8733450>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1dc8739490>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1dc8733f10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f1dc872e990>,
#   <matplotlib.lines.Line2D at 0x7f1dc872eed0>]}

# %%
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
df1=df[["valence","energy"]]

# %%
df1
# Out:
#         valence  energy
# 0        0.1270  0.4450
# 1        0.6550  0.2630
# 2        0.4570  0.1770
# 3        0.3970  0.0946
# 4        0.1960  0.1580
# ...         ...     ...
# 586667   0.2110  0.5180
# 586668   0.6860  0.6630
# 586669   0.0663  0.3140
# 586670   0.4380  0.6150
# 586671   0.9750  0.7230
#
# [586672 rows x 2 columns]

# %%
kmeans = KMeans(n_clusters=2)

# %%
#predict the labels of clusters.
label = kmeans.fit_predict(df1)

# %%
print(label)
# Out:
# [0 0 0 ... 0 1 1]

# %%
#filter rows of original data
filtered_label0 = df1[label == 0]
filtered_label1 = df1[label == 1]
#plotting the results
plt.scatter(filtered_label0["valence"] , filtered_label0["energy"] , color = "red")
plt.scatter(filtered_label1["valence"] , filtered_label1["energy"] , color = "green")
plt.show()

# %%
filtered_label1 = df1[label == 1]
filtered_label1
# Out:
#         valence  energy
# 6         0.727   0.355
# 13        0.897   0.280
# 14        0.840   0.289
# 19        0.753   0.372
# 28        0.766   0.408
# ...         ...     ...
# 586663    0.908   0.970
# 586664    0.395   0.679
# 586668    0.686   0.663
# 586670    0.438   0.615
# 586671    0.975   0.723
#
# [332870 rows x 2 columns]

# %%
print("cluster 0 Range of valence : ",filtered_label0['valence'].min(),":",filtered_label0['valence'].max())
print("cluster 0 Range of energy : ",filtered_label0['energy'].min(),":",filtered_label0['energy'].max())

print("\n\ncluster 1 Range of valence : ",filtered_label1['valence'].min(),":",filtered_label1['valence'].max())
print("cluster 1 Range of energy : ",filtered_label1['energy'].min(),":",filtered_label1['energy'].max())
# Out:
# cluster 0 Range of valence :  0.0 : 0.981
# cluster 0 Range of energy :  0.0 : 1.0
#
#
# cluster 1 Range of valence :  0.0693 : 1.0
# cluster 1 Range of energy :  0.0602 : 1.0

# %%
kmeans1 = KMeans(n_clusters=4)

# %%
#predict the labels of clusters.
label1 = kmeans1.fit_predict(df1)

# %%
print(label1)
# Out:
# [1 3 1 ... 1 2 0]

# %%
filtered_label00 = df1[label1 == 0]
filtered_label01 = df1[label1 == 1]
filtered_label02 = df1[label1 == 2]
filtered_label03 = df1[label1 == 3]

filtered00 = df[label1 == 0].copy(deep=True)
filtered01 = df[label1 == 1].copy(deep=True)
filtered02 = df[label1 == 2].copy(deep=True)
filtered03 = df[label1 == 3].copy(deep=True)

# %%
plt.scatter(filtered_label00["valence"] , filtered_label00["energy"] , color="red")
plt.scatter(filtered_label01["valence"] , filtered_label01["energy"] , color="blue")
plt.scatter(filtered_label02["valence"] , filtered_label02["energy"] , color="green")
plt.scatter(filtered_label03["valence"] , filtered_label03["energy"] , color="black")
plt.show()

# %%
filtered00.size
# Out:
# 3365540

# %%
filtered01.size
# Out:
# 2897520

# %%
print("range of popularities :",df['popularity'].min() , ":" , df['popularity'].max())
print("\ncluster 0 avg popularities :",filtered00['popularity'].mean())
print("cluster 1 avg popularities :",filtered01['popularity'].mean())
print("cluster 2 avg popularities :",filtered02['popularity'].mean())
print("cluster 3 avg popularities :",filtered03['popularity'].mean())
# Out:
# range of popularities : 0 : 100
#
# cluster 0 avg popularities : 31.235041033533996
# cluster 1 avg popularities : 23.137538308622545
# cluster 2 avg popularities : 34.251069582382804
# cluster 3 avg popularities : 21.678834561286003

# %%
print("cluster 0 Range of valence : ",filtered_label00['valence'].min(),":",filtered_label00['valence'].max())
print("cluster 0 Range of energy : ",filtered_label00['energy'].min(),":",filtered_label00['energy'].max())

print("\n\ncluster 1 Range of valence : ",filtered_label01['valence'].min(),":",filtered_label01['valence'].max())
print("cluster 1 Range of energy : ",filtered_label01['energy'].min(),":",filtered_label01['energy'].max())

print("\n\ncluster 2 Range of valence : ",filtered_label02['valence'].min(),":",filtered_label02['valence'].max())
print("cluster 2 Range of energy : ",filtered_label02['energy'].min(),":",filtered_label02['energy'].max())

print("\n\ncluster 3 Range of valence : ",filtered_label03['valence'].min(),":",filtered_label03['valence'].max())
print("cluster 3 Range of energy : ",filtered_label03['energy'].min(),":",filtered_label03['energy'].max())
# Out:
# cluster 0 Range of valence :  0.583 : 1.0
# cluster 0 Range of energy :  0.503 : 1.0
#
#
# cluster 1 Range of valence :  0.0 : 0.569
# cluster 1 Range of energy :  0.0 : 0.584
#
#
# cluster 2 Range of valence :  0.0 : 0.607
# cluster 2 Range of energy :  0.469 : 1.0
#
#
# cluster 3 Range of valence :  0.435 : 1.0
# cluster 3 Range of energy :  0.00017900000000000001 : 0.621

# %%
print("cluster 0 Range of valence : ",filtered00['valence'].min(),":",filtered00['valence'].max())
print("cluster 0 Range of energy : ",filtered00['energy'].min(),":",filtered00['energy'].max())

print("\n\ncluster 1 Range of valence : ",filtered01['valence'].min(),":",filtered01['valence'].max())
print("cluster 1 Range of energy : ",filtered01['energy'].min(),":",filtered01['energy'].max())

print("\n\ncluster 2 Range of valence : ",filtered02['valence'].min(),":",filtered02['valence'].max())
print("cluster 2 Range of energy : ",filtered02['energy'].min(),":",filtered02['energy'].max())

print("\n\ncluster 3 Range of valence : ",filtered03['valence'].min(),":",filtered03['valence'].max())
print("cluster 3 Range of energy : ",filtered03['energy'].min(),":",filtered03['energy'].max())
# Out:
# cluster 0 Range of valence :  0.583 : 1.0
# cluster 0 Range of energy :  0.503 : 1.0
#
#
# cluster 1 Range of valence :  0.0 : 0.569
# cluster 1 Range of energy :  0.0 : 0.584
#
#
# cluster 2 Range of valence :  0.0 : 0.607
# cluster 2 Range of energy :  0.469 : 1.0
#
#
# cluster 3 Range of valence :  0.435 : 1.0
# cluster 3 Range of energy :  0.00017900000000000001 : 0.621

# %%
filtered00.head()
# Out:
#                          id  ... time_signature
# 274  0ZRoSs5icoW5QJvZq0Y73w  ...              4
# 300  10qdz1AgvZt7ZKWi58Wutx  ...              4
# 609  5wBkFVpjJiuRi8ZomCngAU  ...              4
# 723  0V29uZ25OVqdQeB7uOeUv3  ...              4
# 758  1JKGMzesB5AMCp9Yuqbcjj  ...              4
#
# [5 rows x 20 columns]

# %%
filtered00["Label"] ="Angry"

# %%
filtered00.head()
# Out:
#                          id  ...  Label
# 274  0ZRoSs5icoW5QJvZq0Y73w  ...  Angry
# 300  10qdz1AgvZt7ZKWi58Wutx  ...  Angry
# 609  5wBkFVpjJiuRi8ZomCngAU  ...  Angry
# 723  0V29uZ25OVqdQeB7uOeUv3  ...  Angry
# 758  1JKGMzesB5AMCp9Yuqbcjj  ...  Angry
#
# [5 rows x 21 columns]

# %%
filtered00.isnull().sum()
# Out:
# id                  0
# name                7
# popularity          0
# duration_ms         0
# explicit            0
# artists             0
# id_artists          0
# release_date        0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# Label               0
# dtype: int64

# %%
filtered01["Label"] ="Happy"

# %%
filtered02["Label"] ="Sad"

# %%
filtered03["Label"] ="Relaxed"

# %%
filtered00.describe()
# Out:
#           popularity   duration_ms  ...          tempo  time_signature
# count  168277.000000  1.682770e+05  ...  168277.000000    168277.00000
# mean       31.235041  2.233689e+05  ...     124.285275         3.95918
# std        17.033262  8.346472e+04  ...      27.657365         0.27019
# min         0.000000  1.641600e+04  ...      34.814000         1.00000
# 25%        19.000000  1.802000e+05  ...     102.287000         4.00000
# 50%        31.000000  2.154530e+05  ...     122.878000         4.00000
# 75%        43.000000  2.558270e+05  ...     140.008000         4.00000
# max        97.000000  5.042185e+06  ...     231.459000         5.00000
#
# [8 rows x 15 columns]

# %%
filtered01.describe()
# Out:
#           popularity   duration_ms  ...          tempo  time_signature
# count  144876.000000  1.448760e+05  ...  144876.000000   144876.000000
# mean       23.137538  2.489373e+05  ...     109.434019        3.758559
# std        17.958075  1.652959e+05  ...      30.586956        0.635676
# min         0.000000  3.344000e+03  ...       0.000000        0.000000
# 25%         7.000000  1.779600e+05  ...      84.010000        4.000000
# 50%        22.000000  2.218760e+05  ...     106.175000        4.000000
# 75%        36.000000  2.786785e+05  ...     130.087250        4.000000
# max        99.000000  5.403500e+06  ...     238.895000        5.000000
#
# [8 rows x 15 columns]

# %%
filtered02.describe()
# Out:
#           popularity   duration_ms  ...          tempo  time_signature
# count  130191.000000  1.301910e+05  ...  130191.000000   130191.000000
# mean       34.251070  2.486809e+05  ...     123.007265        3.933398
# std        18.315514  1.359441e+05  ...      28.715193        0.351065
# min         0.000000  4.937000e+03  ...       0.000000        0.000000
# 25%        22.000000  1.976000e+05  ...      99.980000        4.000000
# 50%        35.000000  2.351520e+05  ...     123.942000        4.000000
# 75%        47.000000  2.814400e+05  ...     140.036000        4.000000
# max       100.000000  5.621218e+06  ...     224.437000        5.000000
#
# [8 rows x 15 columns]

# %%
filtered03.describe()
# Out:
#           popularity   duration_ms  ...          tempo  time_signature
# count  143328.000000  1.433280e+05  ...  143328.000000   143328.000000
# mean       21.678835  2.018843e+05  ...     116.633591        3.834198
# std        17.296918  1.068767e+05  ...      29.818854        0.532465
# min         0.000000  1.530700e+04  ...      30.506000        0.000000
# 25%         6.000000  1.529600e+05  ...      94.760000        4.000000
# 50%        20.000000  1.887995e+05  ...     114.059000        4.000000
# 75%        34.000000  2.350940e+05  ...     133.174000        4.000000
# max        97.000000  3.659207e+06  ...     246.381000        5.000000
#
# [8 rows x 15 columns]

# %%
finalDF = filtered00.append(filtered01)

# %%
finalDF.describe()
# Out:
#           popularity   duration_ms  ...          tempo  time_signature
# count  313153.000000  3.131530e+05  ...  313153.000000   313153.000000
# mean       27.488841  2.351978e+05  ...     117.414542        3.866366
# std        17.927717  1.286329e+05  ...      29.978324        0.485982
# min         0.000000  3.344000e+03  ...       0.000000        0.000000
# 25%        13.000000  1.792520e+05  ...      94.492000        4.000000
# 50%        27.000000  2.178400e+05  ...     116.264000        4.000000
# 75%        40.000000  2.654930e+05  ...     135.793000        4.000000
# max        99.000000  5.403500e+06  ...     238.895000        5.000000
#
# [8 rows x 15 columns]

# %%
finalDF = finalDF.append(filtered02)

# %%
finalDF.describe()
# Out:
#           popularity   duration_ms  ...          tempo  time_signature
# count  443344.000000  4.433440e+05  ...  443344.000000   443344.000000
# mean       29.474616  2.391572e+05  ...     119.056884        3.886050
# std        18.303405  1.309662e+05  ...      29.722296        0.451605
# min         0.000000  3.344000e+03  ...       0.000000        0.000000
# 25%        15.000000  1.839145e+05  ...      95.972000        4.000000
# 50%        29.000000  2.233330e+05  ...     118.951000        4.000000
# 75%        42.000000  2.705760e+05  ...     137.459000        4.000000
# max       100.000000  5.621218e+06  ...     238.895000        5.000000
#
# [8 rows x 15 columns]

# %%
finalDF = finalDF.append(filtered03)

# %%
finalDF.describe()
# Out:
#           popularity   duration_ms  ...          tempo  time_signature
# count  586672.000000  5.866720e+05  ...  586672.000000   586672.000000
# mean       27.570053  2.300512e+05  ...     118.464857        3.873382
# std        18.370642  1.265261e+05  ...      29.764108        0.473162
# min         0.000000  3.344000e+03  ...       0.000000        0.000000
# 25%        13.000000  1.750930e+05  ...      95.600000        4.000000
# 50%        27.000000  2.148930e+05  ...     117.384000        4.000000
# 75%        41.000000  2.638670e+05  ...     136.321000        4.000000
# max       100.000000  5.621218e+06  ...     246.381000        5.000000
#
# [8 rows x 15 columns]

# %%
finalDF.head()
# Out:
#                          id  ...  Label
# 274  0ZRoSs5icoW5QJvZq0Y73w  ...  Angry
# 300  10qdz1AgvZt7ZKWi58Wutx  ...  Angry
# 609  5wBkFVpjJiuRi8ZomCngAU  ...  Angry
# 723  0V29uZ25OVqdQeB7uOeUv3  ...  Angry
# 758  1JKGMzesB5AMCp9Yuqbcjj  ...  Angry
#
# [5 rows x 21 columns]

# %%
finalDF.to_csv('/content/drive/MyDrive/datasetwithLabel.csv')

# %% [markdown]
# Extra code

# %%
filtered00.append(filtered02)
# Out:
#                             id  ...  Label
# 1       021ht4sdgPcrDgSk7JTbKY  ...  Angry
# 6       0Dd9ImXtAtGwsmsAD69KZT  ...  Angry
# 7       0IA0Hju8CAgYfV1hwhidBH  ...  Angry
# 8       0IgI1UCz84pYeVetnl1lGP  ...  Angry
# 9       0JV4iqw2lSKJaHBQZ0e5zK  ...  Angry
# ...                        ...  ...    ...
# 586656  65hdygJXXOBGKS76EKvxth  ...    Sad
# 586658  6IGuPIQaRd7PPsKO35N1dv  ...    Sad
# 586664  1Kzjk1EyngBcP4T8x3fyqv  ...    Sad
# 586666  1ZwZsVZUiyFwIHMNpI3ERt  ...    Sad
# 586670  45XJsGpFTyzbzeWK8VzR8S  ...    Sad
#
# [273761 rows x 21 columns]

# %%
filtered00.append(filtered03)
# Out:
#                             id  ...    Label
# 1       021ht4sdgPcrDgSk7JTbKY  ...    Angry
# 6       0Dd9ImXtAtGwsmsAD69KZT  ...    Angry
# 7       0IA0Hju8CAgYfV1hwhidBH  ...    Angry
# 8       0IgI1UCz84pYeVetnl1lGP  ...    Angry
# 9       0JV4iqw2lSKJaHBQZ0e5zK  ...    Angry
# ...                        ...  ...      ...
# 586661  27kcZEJvhkb1rzZS9gCpdA  ...  Relaxed
# 586662  4Zp3rm12p5PiHToYJflmyy  ...  Relaxed
# 586665  0SjsIzJkZfDU7wlcdklEFR  ...  Relaxed
# 586667  5rgu12WBIHQtvej2MdHSH0  ...  Relaxed
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2  ...  Relaxed
#
# [289494 rows x 21 columns]

# %%
filtered00
# Out:
#                             id  ...  Label
# 1       021ht4sdgPcrDgSk7JTbKY  ...  Angry
# 6       0Dd9ImXtAtGwsmsAD69KZT  ...  Angry
# 7       0IA0Hju8CAgYfV1hwhidBH  ...  Angry
# 8       0IgI1UCz84pYeVetnl1lGP  ...  Angry
# 9       0JV4iqw2lSKJaHBQZ0e5zK  ...  Angry
# ...                        ...  ...    ...
# 586607  1zmMf0f4YchxURhvY30L8g  ...  Angry
# 586623  28TbObgGrTSyrfYl6KAnZH  ...  Angry
# 586632  4l9Rzfhif755mKMZi0D7SN  ...  Angry
# 586645  44r4zta6P9flkhKaVnbsvG  ...  Angry
# 586657  1dKxf4Ht2SsKLyXfSDJAgy  ...  Angry
#
# [143656 rows x 21 columns]

# %%
filtered00.nunique()
# Out:
# id                  143656
# name                120390
# popularity              94
# duration_ms          52042
# explicit                 2
# artists              35015
# id_artists           35160
# release_date         14070
# danceability           848
# energy                1326
# key                     12
# loudness             19568
# mode                     2
# speechiness           1649
# acousticness          3025
# instrumentalness      5385
# liveness              1715
# valence                561
# tempo                76664
# time_signature           5
# Label                    1
# dtype: int64
