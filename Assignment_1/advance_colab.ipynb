# %%
# wget to download
# !wget https://losc.ligo.net/s/events/LOSC_Event_tutorial.zip
# Out:
# --2024-09-06 02:21:28--  https://losc.ligo.net/s/events/LOSC_Event_tutorial.zip
# Resolving losc.ligo.net (losc.ligo.net)... 54.237.57.21, 3.233.30.191
# Connecting to losc.ligo.net (losc.ligo.net)|54.237.57.21|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.namepros.com/parked/losc.ligo.net?referrer= [following]
# --2024-09-06 02:21:28--  https://www.namepros.com/parked/losc.ligo.net?referrer=
# Resolving www.namepros.com (www.namepros.com)... 104.26.11.237, 172.67.72.183, 104.26.10.237, ...
# Connecting to www.namepros.com (www.namepros.com)|104.26.11.237|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘LOSC_Event_tutorial.zip’
#
# LOSC_Event_tutorial     [ <=>                ]  19.78K  --.-KB/s    in 0s
#
# 2024-09-06 02:21:29 (114 MB/s) - ‘LOSC_Event_tutorial.zip’ saved [20253]

# %%
#And unzip into current directory
# !unzip -j LOSC_Event_tutorial.zip LOSC_Event_tutorial/*.*
# Out:
# Archive:  LOSC_Event_tutorial.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of LOSC_Event_tutorial.zip or
#         LOSC_Event_tutorial.zip.zip, and cannot find LOSC_Event_tutorial.zip.ZIP, period.

# %%
#connect to google drive with mount
from google.colab import drive
drive.mount('mount')
# Out:
# Mounted at mount

# %%
#copy a file there to here
from google.colab import drive
drive.mount('/content/drive')
# !cp "/content/drive/My Drive/ansible-intro.pdf" /content/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp "/content/drive/My Drive/ansible-intro.pdf" /content/

# %%
# Dowload public a public file
# !gdown --id 0B7XkCwpI5KDYNlNUTTlSS21pQmM
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM
# From (redirected): https://drive.google.com/uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM&confirm=t&uuid=992c6cee-90a8-4efd-8656-d5e23e64b8c8
# To: /content/GoogleNews-vectors-negative300.bin.gz
# 100% 1.65G/1.65G [00:21<00:00, 75.0MB/s]

# %%
# !ls -al  * .zip
# Out:
# ls: cannot access '.zip': No such file or directory
# -rw------- 1 root root    1082568 Sep  9 06:04 ansible-intro.pdf
# -rw-r--r-- 1 root root 1647046227 Sep  9 05:53 GoogleNews-vectors-negative300.bin.gz
#
# drive:
# total 16
# dr-x------ 2 root root 4096 Sep  9 06:03 .file-revisions-by-id
# drwx------ 3 root root 4096 Sep  9 06:03 MyDrive
# dr-x------ 2 root root 4096 Sep  9 06:03 .shortcut-targets-by-id
# drwx------ 5 root root 4096 Sep  9 06:03 .Trash-0
#
# sample_data:
# total 55512
# drwxr-xr-x 1 root root     4096 Sep  5 17:47 .
# drwxr-xr-x 1 root root     4096 Sep  9 06:04 ..
# -rwxr-xr-x 1 root root     1697 Jan  1  2000 anscombe.json
# -rw-r--r-- 1 root root   301141 Sep  5 17:47 california_housing_test.csv
# -rw-r--r-- 1 root root  1706430 Sep  5 17:47 california_housing_train.csv
# -rw-r--r-- 1 root root 18289443 Sep  5 17:47 mnist_test.csv
# -rw-r--r-- 1 root root 36523880 Sep  5 17:47 mnist_train_small.csv
# -rwxr-xr-x 1 root root      930 Jan  1  2000 README.md

# %%
#authintecate (another one)
from google.colab import auth
auth.authenticate_user()

# %%
#I want to download this folder
folder_id = '1V-tWY-qafK7Q-l1jBUQCMbKI9g8UJHLo'

# %%
''' list all ids of the directly under this folder'''
def folder_list(folder_id):
  from googleapiclient.discovery import build
  gdrive=build('drive','v3').files()
  res=gdrive.list(q= "'%s' in parents" % folder_id).execute()
  return [f['id'] for f in res['files']]

# %%
folder_list(folder_id)
# Out:
# ['1TmnwfTQ5HOKnPflQoxjCgT12qApYl7iW', '1ewentseI-fZXWwV5kzPrs0_jdMb6l0Vl']

# %%
#download them one by one
def folder_download(folder_id):
 for fid in folder_list(folder_id):
  # !gdown --fuzzy "https://drive.google.com/drive/u/0/folders/1V-tWY-qafK7Q-l1jBUQCMbKI9g8UJHLo"

# %%
folder_download(folder_id)
# Out:
# Downloading...
# From: https://drive.google.com/drive/u/0/folders/1V-tWY-qafK7Q-l1jBUQCMbKI9g8UJHLo
# To: /content/1V-tWY-qafK7Q-l1jBUQCMbKI9g8UJHLo
# 1.25MB [00:00, 49.8MB/s]
# Downloading...
# From: https://drive.google.com/drive/u/0/folders/1V-tWY-qafK7Q-l1jBUQCMbKI9g8UJHLo
# To: /content/1V-tWY-qafK7Q-l1jBUQCMbKI9g8UJHLo
# 1.25MB [00:00, 56.5MB/s]

# %%
import re
from IPython.display import HTML
from IPython.core.magic import register_cell_magic

# %%
def var_sub(m):
  v = globals()[m[1]]
  if type(v) != str:
    v = repr(v)
    return v
