# %% [markdown]
# # Import libraries
#
# Here we imported neccessary **libraries** used in this ***notebook***

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import svm

# %%
import py3dmol #Import the module
p = py3dmol.view(query = 'mmtf:1ycr')
p.setStyle({'cartoon':{'color':'spectrum'}})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-5285b85f4cd8> in <cell line: 1>()
# ----> 1 import py3dmol #Import the module
#       2 p = py3dmol.view(query = 'mmtf:1ycr')
#       3 p.setStyle({'cartoon':{'color':'spectrum'}})
#
# ModuleNotFoundError: No module named 'py3dmol'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Text example

# %% [markdown]
# # Heading 1
#
# This represents heading content

# %%
a =1

# %%
b ="data"

# %%
c = [1,2,3]

# %%
d = ['rutu','sai','rushabh']

# %%
for i,j in zip(c,d):
  if i == 1:
    print(j + ' has ' + str(i) + ' car ')
  else:
    print(j + ' has ' + str(i) + ' cars ')
# Out:
# rutu has 1 car
# sai has 2 cars
# rushabh has 3 cars

# %% [markdown]
# ## Heading 1.1

# %% [markdown]
# ## Heading 1.2

# %% [markdown]
# ### Heading 1.2.1

# %% [markdown]
# H

# %% [markdown]
# ### Heading 1.2.2

# %% [markdown]
# #Heading 2
